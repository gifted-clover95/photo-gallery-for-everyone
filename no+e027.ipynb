# %% [markdown]
# <a href="https://colab.research.google.com/github/gifted-clover95/photo-gallery-for-everyone/blob/main/no%2Be027.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
width = 1280; height = 670 # みんなのフォトギャラリー用にサイズを指定

im = np.ones((height, width))

# %%
# i,j が互いに素の所は黒、それ以外は白を格納
r = 10
for i in range (height//r):
    for j in range (width//r):
        c = 0 if math.gcd(i+1,j+1) == 1 else 255
        for i0 in range(r):
            for j0 in range(r):
                im[r*i+i0][r*j+j0] = c

# %%
#画像の表示と保存
plt.imshow(im, cmap='gray')
plt.axis('off')
plt.show()

plt.imsave('no+e_photo_gallery_027.png', im, cmap='gray',dpi=1000 )
